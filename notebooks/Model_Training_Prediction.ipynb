# %%
import pandas as pd
from sklearn.preprocessing import RobustScaler
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv("Wildlife_Dataset_Top6.csv")

# %% [markdown]
# Creating the Feature Matrix

# %%
feature_df = (
    df
    .groupby(['Taxon', 'Exporter'])
    .agg(
        appendix_risk = ('App.', 'mean'),
        import_qty_log = ('import_qty_log', 'sum'),
        export_qty_log = ('export_qty_log', 'sum'),
        live_trade_ratio = ('is_live', 'mean'),
        purpose_risk = ('Purpose', 'mean'),
        source_risk = ('Source', 'mean'),
        num_trade_events = ('Exporter', 'count')
    )
    .reset_index()
)

# %%
feature_df.head()
# Out:
#                         Taxon             Exporter  appendix_risk  \
# 0  Alligator Mississippiensis              Albania            2.0
# 1  Alligator Mississippiensis              Andorra            2.0
# 2  Alligator Mississippiensis  Antigua and Barbuda            2.0
# 3  Alligator Mississippiensis            Argentina            2.0
# 4  Alligator Mississippiensis            Australia            2.0
#
#    import_qty_log  export_qty_log  live_trade_ratio  purpose_risk  \
# 0        0.693147        0.000000               0.0           3.0
# 1        1.609438        0.000000               0.0           3.0
# 2        0.693147        0.000000               0.0           3.0
# 3        0.000000        4.442651               0.0           3.0
# 4       21.817762        0.000000               0.0           3.0
#
#    source_risk  num_trade_events
# 0     3.000000                 1
# 1     3.000000                 1
# 2     3.000000                 1
# 3     3.000000                 1
# 4     2.636364                11

# %%
feature_df.to_csv("Feature_Matrix.csv", index=False)
from google.colab import files
files.download("Feature_Matrix.csv")

# %%
# drop categorical columns
id_cols = ['Taxon', 'Exporter']
X = feature_df.drop(columns=id_cols)

# %%
# create taxonomy lookup table
taxonomy_lookup = (
    df[['Taxon', 'Order', 'Family', 'Genus']]
    .drop_duplicates()
)

# %%
X.describe()
# Out:
#        appendix_risk  import_qty_log  export_qty_log  live_trade_ratio  \
# count     357.000000      357.000000      357.000000        357.000000
# mean        2.026048       36.788232       58.593105          0.047081
# std         0.122931       84.582167      173.187719          0.187991
# min         2.000000        0.000000        0.000000          0.000000
# 25%         2.000000        1.386294        0.000000          0.000000
# 50%         2.000000        5.894403        3.663562          0.000000
# 75%         2.000000       32.583766       30.121181          0.000000
# max         3.000000      762.085341     1553.938299          1.000000
#
#        purpose_risk  source_risk  num_trade_events
# count    357.000000   357.000000        357.000000
# mean       2.835210     1.970360         28.235294
# std        0.328915     0.799381         71.464225
# min        1.000000     1.000000          1.000000
# 25%        2.875000     1.073171          2.000000
# 50%        3.000000     2.000000          5.000000
# 75%        3.000000     2.900000         24.000000
# max        3.000000     3.000000        702.000000

# %% [markdown]
# Scaling the Feature Matrix

# %%
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled.shape
# Out:
# (357, 7)

# %% [markdown]
# Training Isolation Forest Model

# %%
iso_model = IsolationForest(
    n_estimators=300,
    contamination=0.08,   # ~5–10% risky cases
    random_state=42
)

iso_model.fit(X_scaled)
# Out:
# IsolationForest(contamination=0.08, n_estimators=300, random_state=42)

# %% [markdown]
# Generate Risk Scores for each Species

# %%
# Raw anomaly scores (higher = riskier)
risk_scores_raw = -iso_model.decision_function(X_scaled)

# %%
risk_scaler = MinMaxScaler()
poaching_risk_score = risk_scaler.fit_transform(
    risk_scores_raw.reshape(-1, 1)
).ravel()

# %%
feature_df['poaching_risk_score'] = poaching_risk_score

# %% [markdown]
# Generate Risk Score and highest-risk country per species

# %%
species_poaching_risk = (
    feature_df
    .sort_values('poaching_risk_score', ascending=False)
    .groupby('Taxon', as_index=False)
    .first()
)

# %%
final_result = species_poaching_risk[
    ['Taxon', 'Exporter', 'poaching_risk_score']
].rename(columns={
    'Exporter': 'likely_poaching_country'
})

# %%
final_result = final_result.merge(
    taxonomy_lookup,
    on='Taxon',
    how='left'
)

# %%
final_result.head()
# Out:
#                         Taxon likely_poaching_country  poaching_risk_score  \
# 0  Alligator Mississippiensis           United States             0.803649
# 1        Crocodylus Niloticus                   Italy             1.000000
# 2          Crocodylus Porosus                  France             0.858284
# 3           Python Bivittatus                   Italy             0.724669
# 4          Python Reticulatus                   Italy             0.982608
#
#         Order         Family       Genus
# 0  Crocodylia  Alligatoridae   Alligator
# 1  Crocodylia   Crocodylidae  Crocodylus
# 2  Crocodylia   Crocodylidae  Crocodylus
# 3   Serpentes     Pythonidae      Python
# 4   Serpentes     Pythonidae      Python

# %%
final_result.to_csv("Final_Output.csv", index=False)
from google.colab import files
files.download("Final_Output.csv")

# %% [markdown]
# Validation

# %%
validation_df = final_result.merge(
    appendix_max,
    left_on=['Taxon', 'likely_poaching_country'],
    right_on=['Taxon', 'Exporter'],
    how='left'
)

validation_df.groupby('appendix_max')['poaching_risk_score'].mean()
# Out:
# appendix_max
# 2.0    0.788296
# 3.0    0.929142
# Name: poaching_risk_score, dtype: float64
